# %% [markdown]
# <a href="https://colab.research.google.com/github/anisfreelancer71/kapal_titanic/blob/main/_02_Dataset%2C_Target_Variable%2C_dan_Missing_Values!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_loan = pd.read_csv("/content/drive/MyDrive/filecsv/lc_2016_2017.csv")

# %%
data_loan.shape
# Out:
# (14016, 72)

# %%
data_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14016 entries, 0 to 14015
# Data columns (total 72 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           14016 non-null  int64
#  1   member_id                    0 non-null      float64
#  2   loan_amnt                    14016 non-null  int64
#  3   funded_amnt                  14016 non-null  int64
#  4   funded_amnt_inv              14016 non-null  int64
#  5   term                         14016 non-null  object
#  6   int_rate                     14016 non-null  float64
#  7   installment                  14016 non-null  float64
#  8   grade                        14016 non-null  object
#  9   sub_grade                    14016 non-null  object
#  10  emp_title                    13169 non-null  object
#  11  emp_length                   13188 non-null  object
#  12  home_ownership               14016 non-null  object
#  13  annual_inc                   14016 non-null  float64
#  14  verification_status          14016 non-null  object
#  15  issue_d                      14016 non-null  object
#  16  loan_status                  14016 non-null  object
#  17  pymnt_plan                   14016 non-null  object
#  18  desc                         0 non-null      float64
#  19  purpose                      14016 non-null  object
#  20  title                        14016 non-null  object
#  21  zip_code                     14016 non-null  object
#  22  addr_state                   14016 non-null  object
#  23  dti                          14005 non-null  float64
#  24  delinq_2yrs                  14016 non-null  int64
#  25  earliest_cr_line             14016 non-null  object
#  26  inq_last_6mths               14016 non-null  int64
#  27  mths_since_last_delinq       7144 non-null   float64
#  28  mths_since_last_record       2606 non-null   float64
#  29  open_acc                     14016 non-null  int64
#  30  pub_rec                      14016 non-null  int64
#  31  revol_bal                    14016 non-null  int64
#  32  revol_util                   14007 non-null  float64
#  33  total_acc                    14016 non-null  int64
#  34  initial_list_status          14016 non-null  object
#  35  out_prncp                    14016 non-null  float64
#  36  out_prncp_inv                14016 non-null  float64
#  37  total_pymnt                  14016 non-null  float64
#  38  total_pymnt_inv              14015 non-null  float64
#  39  total_rec_prncp              14015 non-null  float64
#  40  total_rec_int                14015 non-null  float64
#  41  total_rec_late_fee           14015 non-null  float64
#  42  recoveries                   14015 non-null  float64
#  43  collection_recovery_fee      14015 non-null  float64
#  44  last_pymnt_d                 13996 non-null  object
#  45  last_pymnt_amnt              14015 non-null  float64
#  46  next_pymnt_d                 13051 non-null  object
#  47  last_credit_pull_d           14015 non-null  object
#  48  collections_12_mths_ex_med   14015 non-null  float64
#  49  mths_since_last_major_derog  3897 non-null   float64
#  50  policy_code                  14015 non-null  float64
#  51  application_type             14015 non-null  object
#  52  annual_inc_joint             1093 non-null   float64
#  53  dti_joint                    1093 non-null   float64
#  54  verification_status_joint    1093 non-null   object
#  55  acc_now_delinq               14015 non-null  float64
#  56  tot_coll_amt                 14015 non-null  float64
#  57  tot_cur_bal                  14015 non-null  float64
#  58  open_acc_6m                  14015 non-null  float64
#  59  open_il_12m                  14015 non-null  float64
#  60  open_il_24m                  14015 non-null  float64
#  61  mths_since_rcnt_il           13590 non-null  float64
#  62  total_bal_il                 14015 non-null  float64
#  63  il_util                      12107 non-null  float64
#  64  open_rv_12m                  14015 non-null  float64
#  65  open_rv_24m                  14015 non-null  float64
#  66  max_bal_bc                   14015 non-null  float64
#  67  all_util                     14014 non-null  float64
#  68  total_rev_hi_lim             14015 non-null  float64
#  69  inq_fi                       14015 non-null  float64
#  70  total_cu_tl                  14015 non-null  float64
#  71  inq_last_12m                 14015 non-null  float64
# dtypes: float64(41), int64(10), object(21)
# memory usage: 7.7+ MB

# %%
data_loan.loan_status.unique()
# Out:
# array(['Current', 'Fully Paid', 'In Grace Period', 'Late (31-120 days)',
#        'Late (16-30 days)', 'Charged Off'], dtype=object)

# %%
data_loan['good_bad'] = np.where(data_loan.loc[:, 'loan_status'].isin(['Charged off', 'Default', 'Late(16-30 days)']),1,0)

# %%
data_loan.good_bad.value_counts()
# Out:
# 0    14016
# Name: good_bad, dtype: int64

# %%
data_loan[['loan_status' , 'good_bad']]
# Out:
#       loan_status  good_bad
# 0         Current         0
# 1         Current         0
# 2         Current         0
# 3         Current         0
# 4         Current         0
# ...           ...       ...
# 14011     Current         0
# 14012     Current         0
# 14013     Current         0
# 14014     Current         0
# 14015     Current         0
#
# [14016 rows x 2 columns]

# %%
missing_values = pd.DataFrame(data_loan.isnull().sum()/data_loan.shape[0])
missing_values
# Out:
#                          0
# id                0.000000
# member_id         1.000000
# loan_amnt         0.000000
# funded_amnt       0.000000
# funded_amnt_inv   0.000000
# ...                    ...
# total_rev_hi_lim  0.000071
# inq_fi            0.000071
# total_cu_tl       0.000071
# inq_last_12m      0.000071
# good_bad          0.000000
#
# [73 rows x 1 columns]

# %%
 missing_values = missing_values[missing_values.iloc[:,0]>0.50]

# %%
missing_values.sort_values([0],ascending=False)
# Out:
#                                     0
# member_id                    1.000000
# desc                         1.000000
# annual_inc_joint             0.922018
# dti_joint                    0.922018
# verification_status_joint    0.922018
# mths_since_last_record       0.814070
# mths_since_last_major_derog  0.721961

# %%
data_loan.dropna(thresh=data_loan.shape[0] * 0.5, axis=1, inplace=True)

# %%
missing_values = pd.DataFrame(data_loan.isnull().sum()/data_loan.shape[0])
missing_values = missing_values[missing_values.iloc[:,0]>0.50]
missing_values.sort_values([0],ascending=False)
# Out:
# Empty DataFrame
# Columns: [0]
# Index: []
